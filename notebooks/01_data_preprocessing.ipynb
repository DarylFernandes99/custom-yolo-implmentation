# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import os
import ijson
import pandas as pd
import dask
import dask.dataframe as ddf
from typing import List, Optional
# dask.config.set({"dataframe.convert-string": False})

# %%
from src.utils.config_loader import load_config
cfg = load_config("../config.yaml")
data_cfg = cfg['data']

# %%
input_dir = os.path.join('..', data_cfg['annotations_dir'])
output_dir = os.path.join('..', data_cfg['processed_dir'])

# %%
def load_annotations_file(file_name: str, key: str, columns: Optional[List[str]] = None, chunk_size=10_000):
    chunks = []
    with open(os.path.join(input_dir, file_name), 'rb') as data:
        # Stream items using ijson
        objects = ijson.items(data, f'{key}.item')
        current_chunk = []
        
        for obj in objects:
            current_chunk.append(obj)
            if len(current_chunk) >= chunk_size:
                chunks.append(pd.DataFrame(current_chunk, columns=columns))
                current_chunk = []
        
        if current_chunk:
            chunks.append(pd.DataFrame(current_chunk, columns=columns))
    
    if not chunks:
        return ddf.from_pandas(pd.DataFrame(columns=columns), npartitions=1)
    
    # Convert list of Pandas DataFrames to a Dask DataFrame
    dask_chunks = [ddf.from_pandas(chunk, npartitions=1) for chunk in chunks]
    return ddf.concat(dask_chunks)

# %%
instances_images = load_annotations_file(
                        file_name="instances_val2017.json",
                        key="images",
                        columns=["file_name", "height", "width", "id"],
                        chunk_size=1_000
                    )
instances_annots = load_annotations_file(
                        file_name="instances_val2017.json",
                        key="annotations",
                        columns=['segmentation', 'area', 'iscrowd', 'image_id', 'bbox', 'category_id', 'id'],
                        chunk_size=10_000
                    )
instances_catego = load_annotations_file(
                        file_name="instances_val2017.json",
                        key="categories",
                        columns=['supercategory', 'id', 'name'],
                        chunk_size=1_000
                    )

# %%
instances_images
# Out:
# Dask DataFrame Structure:
#               file_name height  width     id
# npartitions=5
#                  string  int64  int64  int64
#                     ...    ...    ...    ...
# ...                 ...    ...    ...    ...
#                     ...    ...    ...    ...
#                     ...    ...    ...    ...
# Dask Name: concat, 6 expressions
# Expr=Concat(frames=[df, df, df, df, df], )

# %%
instances_annots
# Out:
# Dask DataFrame Structure:
#               segmentation    area iscrowd image_id    bbox category_id     id
# npartitions=4
#                     string  string   int64    int64  string       int64  int64
#                        ...     ...     ...      ...     ...         ...    ...
#                        ...     ...     ...      ...     ...         ...    ...
#                        ...     ...     ...      ...     ...         ...    ...
#                        ...     ...     ...      ...     ...         ...    ...
# Dask Name: concat, 5 expressions
# Expr=Concat(frames=[df, df, df, df], )

# %%
instances_catego
# Out:
# Dask DataFrame Structure:
#               supercategory     id    name
# npartitions=1
# 0                    string  int64  string
# 79                      ...    ...     ...
# Dask Name: frompandas, 1 expression
# Expr=df

# %%
stuff_images = load_annotations_file(
                        file_name="stuff_val2017.json",
                        key="images",
                        columns=["file_name", "height", "width", "id"],
                        chunk_size=1_000
                    )
stuff_annots = load_annotations_file(
                        file_name="stuff_val2017.json",
                        key="annotations",
                        columns=['segmentation', 'area', 'iscrowd', 'image_id', 'bbox', 'category_id', 'id'],
                        chunk_size=10_000
                    )
stuff_catego = load_annotations_file(
                        file_name="stuff_val2017.json",
                        key="categories",
                        columns=['supercategory', 'id', 'name'],
                        chunk_size=1_000
                    )

# %%
stuff_images
# Out:
# Dask DataFrame Structure:
#               file_name height  width     id
# npartitions=5
#                  string  int64  int64  int64
#                     ...    ...    ...    ...
# ...                 ...    ...    ...    ...
#                     ...    ...    ...    ...
#                     ...    ...    ...    ...
# Dask Name: concat, 6 expressions
# Expr=Concat(frames=[df, df, df, df, df], )

# %%
stuff_annots
# Out:
# Dask DataFrame Structure:
#               segmentation    area iscrowd image_id    bbox category_id     id
# npartitions=4
#                     string  string   int64    int64  string       int64  int64
#                        ...     ...     ...      ...     ...         ...    ...
#                        ...     ...     ...      ...     ...         ...    ...
#                        ...     ...     ...      ...     ...         ...    ...
#                        ...     ...     ...      ...     ...         ...    ...
# Dask Name: concat, 5 expressions
# Expr=Concat(frames=[df, df, df, df], )

# %%
stuff_catego
# Out:
# Dask DataFrame Structure:
#               supercategory     id    name
# npartitions=1
# 0                    string  int64  string
# 91                      ...    ...     ...
# Dask Name: frompandas, 1 expression
# Expr=df

# %%
images_combined = ddf.concat([instances_images, stuff_images], axis=0)
images_combined = images_combined.drop_duplicates()
images_combined
# Out:
# Dask DataFrame Structure:
#                file_name height  width     id
# npartitions=10
#                   string  int64  int64  int64
#                      ...    ...    ...    ...
# ...                  ...    ...    ...    ...
#                      ...    ...    ...    ...
#                      ...    ...    ...    ...
# Dask Name: dropduplicates, 8 expressions
# Expr=DropDuplicates(frame=Concat(frames=[Concat(frames=[df, df, df, df, df], ), Concat(frames=[df, df, df, df, df], )], ))

# %%
images_combined.compute()
# Out:
#             file_name  height  width      id
# 0    000000397133.jpg     427    640  397133
# 1    000000037777.jpg     230    352   37777
# 9    000000331352.jpg     500    351  331352
# 18   000000181666.jpg     425    640  181666
# 23   000000460347.jpg     640    427  460347
# ..                ...     ...    ...     ...
# 952  000000236690.jpg     399    640  236690
# 957  000000272212.jpg     480    640  272212
# 966  000000549220.jpg     640    480  549220
# 969  000000574297.jpg     427    640  574297
# 996  000000168974.jpg     500    375  168974
#
# [5000 rows x 4 columns]

# %%
annots_combined = ddf.concat([instances_annots, stuff_annots], axis=0)
annots_combined = annots_combined.drop_duplicates()
annots_combined
# Out:
# Dask DataFrame Structure:
#               segmentation    area iscrowd image_id    bbox category_id     id
# npartitions=8
#                     string  string   int64    int64  string       int64  int64
#                        ...     ...     ...      ...     ...         ...    ...
# ...                    ...     ...     ...      ...     ...         ...    ...
#                        ...     ...     ...      ...     ...         ...    ...
#                        ...     ...     ...      ...     ...         ...    ...
# Dask Name: dropduplicates, 12 expressions
# Expr=DropDuplicates(frame=Concat(frames=[Concat(frames=[df, df, df, df], ), Concat(frames=[df, df, df, df], )], ))

# %%
annots_combined.compute()
# Out:
#                                            segmentation                area  \
# 9     [[Decimal('115.46'), Decimal('164.53'), Decima...   2613.772699999999
# 13    [[Decimal('387.99'), Decimal('176.5'), Decimal...           2991.9213
# 14    [[Decimal('0.97'), Decimal('59.05'), Decimal('...         179462.9809
# 17    [[Decimal('563.38'), Decimal('247.89'), Decima...  15711.620349999997
# 28    [[Decimal('109.78'), Decimal('1.08'), Decimal(...   27667.51730000001
# ...                                                 ...                 ...
# 2745  {'counts': 'TPZ51Y=3N2M21O02N2M1O2O1OO02O01O00...              1112.0
# 2762  {'counts': '`7\\1k1YOdN`2Q7WN[JYOdN`2Q7WN[JXOe...             82530.0
# 2768  {'counts': 'e5n3Q`02O2N1N3N23NL2O2M4M2M3N3L100...             79346.0
# 2782  {'counts': 'g^<\\1ha03M3M2M3N1O1O2N1O1O1O1O1O1...             68797.0
# 2796  {'counts': '0[6c0\\Lf4e3ZKZLf4b1mJfM>g0e4U1^KQ...             83419.0
#
#       iscrowd  image_id                                               bbox  \
# 9           0    404484  [Decimal('86.93'), Decimal('90.76'), Decimal('...
# 13          0     65485  [Decimal('387.99'), Decimal('97.43'), Decimal(...
# 14          0    498286  [Decimal('0.97'), Decimal('9.8'), Decimal('467...
# 17          0     67213  [Decimal('402.7'), Decimal('58.79'), Decimal('...
# 28          0    522007  [Decimal('38.74'), Decimal('0.0'), Decimal('16...
# ...       ...       ...                                                ...
# 2745        0    580418  [Decimal('406.0'), Decimal('301.0'), Decimal('...
# 2762        0    581100  [Decimal('0.0'), Decimal('151.0'), Decimal('64...
# 2768        0    581206  [Decimal('0.0'), Decimal('88.0'), Decimal('479...
# 2782        0    581357  [Decimal('20.0'), Decimal('416.0'), Decimal('5...
# 2796        0    581781  [Decimal('0.0'), Decimal('0.0'), Decimal('640....
#
#       category_id        id
# 9              18      7981
# 13             18     10176
# 14             18     12182
# 17             18     13714
# 28             64     20979
# ...           ...       ...
# 2745          162  20032745
# 2762          124  20032762
# 2768          100  20032768
# 2782          144  20032782
# 2796          122  20032796
#
# [69582 rows x 7 columns]

# %%
catego_combined = ddf.concat([instances_catego, stuff_catego], axis=0) \
                    .drop_duplicates() \
                    .reset_index()
catego_combined
# Out:
# Dask DataFrame Structure:
#                index supercategory     id    name
# npartitions=2
#                int64        string  int64  string
#                  ...           ...    ...     ...
#                  ...           ...    ...     ...
# Dask Name: reset_index, 5 expressions
# Expr=ResetIndex(frame=DropDuplicates(frame=Concat(frames=[df, df], )))

# %%
# Rename columns explicitly before merging to prevent ambiguous suffixes
images_renamed = images_combined.rename(columns={"id": "image_id_pk"})
annots_renamed = annots_combined.rename(columns={"id": "annotation_id"})

ddf_combined = ddf.merge(
    left=images_renamed, 
    right=annots_renamed, 
    how="inner", 
    left_on="image_id_pk", 
    right_on="image_id"
).merge(
    catego_combined, 
    how="inner", 
    left_on="category_id", 
    right_on="id"
)
ddf_combined
# Out:
# Dask DataFrame Structure:
#                file_name height  width   id_x segmentation    area iscrowd image_id    bbox category_id   id_y  index supercategory     id    name
# npartitions=10
#                   string  int64  int64  int64       string  string   int64    int64  string       int64  int64  int64        string  int64  string
#                      ...    ...    ...    ...          ...     ...     ...      ...     ...         ...    ...    ...           ...    ...     ...
# ...                  ...    ...    ...    ...          ...     ...     ...      ...     ...         ...    ...    ...           ...    ...     ...
#                      ...    ...    ...    ...          ...     ...     ...      ...     ...         ...    ...    ...           ...    ...     ...
#                      ...    ...    ...    ...          ...     ...     ...      ...     ...         ...    ...    ...           ...    ...     ...
# Dask Name: merge, 27 expressions
# Expr=Merge(8e2b03d)

# %%
# Drop the original category_id and annotation_id first
ddf_combined = ddf_combined.drop(columns=["category_id", "annotation_id"])

# Rename columns to final names
ddf_combined = ddf_combined.rename(columns={
    "image_id_pk": "id", 
    "id": "old_category_id", 
    "index": "category_id"
})
