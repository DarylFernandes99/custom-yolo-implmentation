# %%
import os
import ijson
import dask.bag as db
import pandas as pd
import dask.dataframe as ddf
from dask.diagnostics import ProgressBar

ProgressBar().register()

file_path = "../dataset/annotation/instances_val2017.json"

# %%
def stream_to_partitions(items, chunk_size=50_000):
    batch=[]
    for obj in items:
        batch.append(obj)
        if len(batch) >= chunk_size:
            yield pd.DataFrame(batch)
            batch.clear()
    
    if batch:
        yield pd.DataFrame(batch)

# %%
# --- Annotations ---
with open(file_path, "rb") as f:
    annotations_iter = ijson.items(f, "annotations.item")
    annotations_partitions = list(stream_to_partitions(annotations_iter, chunk_size=5000))

annotations_ddf = ddf.from_pandas(
    pd.concat(annotations_partitions, ignore_index=True),
    npartitions=len(annotations_partitions)
)

# --- Images ---
with open(file_path, "rb") as f:
    images_iter = ijson.items(f, "images.item")
    images_partitions = list(stream_to_partitions(images_iter, chunk_size=1000))

images_ddf = ddf.from_pandas(
    pd.concat(images_partitions, ignore_index=True),
    npartitions=len(images_partitions)
)

# %%
annotations_ddf.drop(columns=["area", "iscrowd", "id"])
annotations_ddf.head()
# Out:
# [########################################] | 100% Completed | 104.08 ms
#                                         segmentation                area  \
# 0  [[Decimal('510.66'), Decimal('423.01'), Decima...   702.1057499999998
# 1  [[Decimal('289.74'), Decimal('443.39'), Decima...  27718.476299999995
# 2  [[Decimal('147.76'), Decimal('396.11'), Decima...   78969.31690000003
# 3  [[Decimal('260.4'), Decimal('231.26'), Decimal...  108316.66515000002
# 4  [[Decimal('200.61'), Decimal('253.97'), Decima...   75864.53530000002
#
#    iscrowd  image_id                                               bbox  \
# 0        0    289343  [Decimal('473.07'), Decimal('395.93'), Decimal...
# 1        0     61471  [Decimal('272.1'), Decimal('200.23'), Decimal(...
# 2        0    472375  [Decimal('124.71'), Decimal('196.18'), Decimal...
# 3        0    520301  [Decimal('112.71'), Decimal('154.82'), Decimal...
# 4        0    579321  [Decimal('200.61'), Decimal('89.65'), Decimal(...
#
#    category_id    id
# 0           18  1768
# 1           18  1773
# 2           18  2551
# 3           18  3186
# 4           18  3419

# %%
images_ddf.head()
# Out:
# [########################################] | 100% Completed | 101.84 ms
#    license         file_name  \
# 0        4  000000397133.jpg
# 1        1  000000037777.jpg
# 2        4  000000252219.jpg
# 3        1  000000087038.jpg
# 4        6  000000174482.jpg
#
#                                             coco_url  height  width  \
# 0  http://images.cocodataset.org/val2017/00000039...     427    640
# 1  http://images.cocodataset.org/val2017/00000003...     230    352
# 2  http://images.cocodataset.org/val2017/00000025...     428    640
# 3  http://images.cocodataset.org/val2017/00000008...     480    640
# 4  http://images.cocodataset.org/val2017/00000017...     388    640
#
#          date_captured                                         flickr_url  \
# 0  2013-11-14 17:02:52  http://farm7.staticflickr.com/6116/6255196340_...
# 1  2013-11-14 20:55:31  http://farm9.staticflickr.com/8429/7839199426_...
# 2  2013-11-14 22:32:02  http://farm4.staticflickr.com/3446/3232237447_...
# 3  2013-11-14 23:11:37  http://farm8.staticflickr.com/7355/8825114508_...
# 4  2013-11-14 23:16:55  http://farm8.staticflickr.com/7020/6478877255_...
#
#        id
# 0  397133
# 1   37777
# 2  252219
# 3   87038
# 4  174482

# %%
images_ddf.drop(columns=["license", "coco_url", "id"])
images_ddf = images_ddf.rename(columns={"id": "image_id"})
images_ddf.head()
# Out:
# [########################################] | 100% Completed | 106.07 ms
#    license         file_name  \
# 0        4  000000397133.jpg
# 1        1  000000037777.jpg
# 2        4  000000252219.jpg
# 3        1  000000087038.jpg
# 4        6  000000174482.jpg
#
#                                             coco_url  height  width  \
# 0  http://images.cocodataset.org/val2017/00000039...     427    640
# 1  http://images.cocodataset.org/val2017/00000003...     230    352
# 2  http://images.cocodataset.org/val2017/00000025...     428    640
# 3  http://images.cocodataset.org/val2017/00000008...     480    640
# 4  http://images.cocodataset.org/val2017/00000017...     388    640
#
#          date_captured                                         flickr_url  \
# 0  2013-11-14 17:02:52  http://farm7.staticflickr.com/6116/6255196340_...
# 1  2013-11-14 20:55:31  http://farm9.staticflickr.com/8429/7839199426_...
# 2  2013-11-14 22:32:02  http://farm4.staticflickr.com/3446/3232237447_...
# 3  2013-11-14 23:11:37  http://farm8.staticflickr.com/7355/8825114508_...
# 4  2013-11-14 23:16:55  http://farm8.staticflickr.com/7020/6478877255_...
#
#    image_id
# 0    397133
# 1     37777
# 2    252219
# 3     87038
# 4    174482

# %%
merged_ddf = annotations_ddf.merge(
    images_ddf,
    on="image_id",
    how="left"
)
merged_ddf.head()
# Out:
# [########################################] | 100% Completed | 106.26 ms
#                                         segmentation                area  \
# 0  [[Decimal('322.06'), Decimal('341.82'), Decima...  344.57855000000023
# 1  [[Decimal('230.48'), Decimal('150.3'), Decimal...  2262.9859499999993
# 2  [[Decimal('45.71'), Decimal('180.09'), Decimal...  1449.4411999999995
# 3  [[Decimal('494.61'), Decimal('156.55'), Decima...           4036.1712
# 4  [[Decimal('29.93'), Decimal('141.43'), Decimal...  47714.037049999984
#
#    iscrowd  image_id                                               bbox  \
# 0        0    227491  [Decimal('307.0'), Decimal('326.77'), Decimal(...
# 1        0    261116  [Decimal('230.48'), Decimal('140.46'), Decimal...
# 2        0    261116  [Decimal('16.08'), Decimal('137.77'), Decimal(...
# 3        0    261116  [Decimal('408.22'), Decimal('111.24'), Decimal...
# 4        0    324715  [Decimal('29.93'), Decimal('71.09'), Decimal('...
#
#    category_id       id  license         file_name  \
# 0           60  1080902        3  000000227491.jpg
# 1           61  1083776        1  000000261116.jpg
# 2           61  1084731        1  000000261116.jpg
# 3           61  1085149        1  000000261116.jpg
# 4           73  1102939        1  000000324715.jpg
#
#                                             coco_url  height  width  \
# 0  http://images.cocodataset.org/val2017/00000022...     480    640
# 1  http://images.cocodataset.org/val2017/00000026...     375    500
# 2  http://images.cocodataset.org/val2017/00000026...     375    500
# 3  http://images.cocodataset.org/val2017/00000026...     375    500
# 4  http://images.cocodataset.org/val2017/00000032...     333    500
#
#          date_captured                                         flickr_url
# 0  2013-11-19 18:13:44  http://farm1.staticflickr.com/41/102772079_df7...
# 1  2013-11-19 21:09:38  http://farm2.staticflickr.com/1226/686014029_4...
# 2  2013-11-19 21:09:38  http://farm2.staticflickr.com/1226/686014029_4...
# 3  2013-11-19 21:09:38  http://farm2.staticflickr.com/1226/686014029_4...
# 4  2013-11-19 22:16:56  http://farm1.staticflickr.com/84/244801562_344...

# %%
image_id_to_find = 397133  # example ID from your dataset

filtered_ddf = merged_ddf[merged_ddf["image_id"] == image_id_to_find]
filtered_df = filtered_ddf.persist()
filtered_ddf
# Out:
# [########################################] | 100% Completed | 106.46 ms
# Dask DataFrame Structure:
#               segmentation    area iscrowd image_id    bbox category_id     id license file_name coco_url height  width date_captured flickr_url
# npartitions=8
#                     string  string   int64    int64  string       int64  int64   int64    string   string  int64  int64        string     string
#                        ...     ...     ...      ...     ...         ...    ...     ...       ...      ...    ...    ...           ...        ...
# ...                    ...     ...     ...      ...     ...         ...    ...     ...       ...      ...    ...    ...           ...        ...
#                        ...     ...     ...      ...     ...         ...    ...     ...       ...      ...    ...    ...           ...        ...
#                        ...     ...     ...      ...     ...         ...    ...     ...       ...      ...    ...    ...           ...        ...
# Dask Name: getitem, 7 expressions
# Expr=Filter(frame=Merge(91f71d9), predicate=Merge(91f71d9)['image_id'] == 397133)
